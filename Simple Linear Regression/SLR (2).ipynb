# %%
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the dataset
data=pd.read_csv("/content/height-weight (1).csv")
print(data)
# Out:
#     Weight  Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %%
data.head(5)
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
#Scatter plot
plt.scatter(data["Weight"], data["Height"])
plt.xlabel("Weight")
plt.ylabel("Height")
plt.title("Height vs Weight")
plt.show()

# %%
# Finding the Correlation
data.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
# Seaborn for Visualization
import seaborn as sns
sns.pairplot(data)

# %%
# Independent and Dependent Feautres
x=data[["Weight"]].values
y=data["Height"].values
print(x)
print(y)
# Out:
# [[ 45]
#  [ 58]
#  [ 48]
#  [ 60]
#  [ 70]
#  [ 78]
#  [ 80]
#  [ 90]
#  [ 95]
#  [ 78]
#  [ 82]
#  [ 95]
#  [105]
#  [100]
#  [ 85]
#  [ 78]
#  [ 50]
#  [ 65]
#  [ 76]
#  [ 87]
#  [ 45]
#  [ 56]
#  [ 72]]
# [120 135 123 145 160 162 163 175 182 170 176 182 175 183 170 177 140 159
#  150 167 129 140 160]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
print(y_train)
# Out:
# [175 135 183 162 123 182 129 145 160 150 140 140 160 175 176 170 167 163]

# %%
print(y_test)
# Out:
# [177 170 120 182 159]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
print(y_pred)
# Out:
# [161.08467086 161.08467086 129.3041561  177.45645118 148.56507414]

# %%
print(y_test)
# Out:
# [177 170 120 182 159]

# %%
# Visualizing the Training Results
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='Blue')
plt.show()

# %%
# Visualizing the testing results
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='Blue')
plt.show()

# %%
# Accuracy Score Calculation
from sklearn.metrics import r2_score
print(r2_score(y_pred,y_test))
# Out:
# 0.570778108534135

# %%
data.isnull().sum()
# Out:
# Weight    0
# Height    0
# dtype: int64

# %% [markdown]
# Salay Prediction Using Experiance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the Dataset
df=pd.read_csv("/content/Salary_dataset.csv")

# %%
print(df)
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df.head(5)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
# Data Analysis
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
# Data distribution
plt.title('Salary Distribution Plot')
sns.distplot(df['Salary'])
plt.show()
# Out:
# <ipython-input-75-ac459df44623>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'])

# %%
# Checking the Relation between the dependent and Independent Feautres
plt.scatter(df["YearsExperience"],df["Salary"])
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Salary Prediction")
plt.show()

# %%
# Splitting the data
X=df[["YearsExperience"]].values
Y=df["Salary"].values

# %%
print(X)
# Out:
# [[ 1.2]
#  [ 1.4]
#  [ 1.6]
#  [ 2.1]
#  [ 2.3]
#  [ 3. ]
#  [ 3.1]
#  [ 3.3]
#  [ 3.3]
#  [ 3.8]
#  [ 4. ]
#  [ 4.1]
#  [ 4.1]
#  [ 4.2]
#  [ 4.6]
#  [ 5. ]
#  [ 5.2]
#  [ 5.4]
#  [ 6. ]
#  [ 6.1]
#  [ 6.9]
#  [ 7.2]
#  [ 8. ]
#  [ 8.3]
#  [ 8.8]
#  [ 9.1]
#  [ 9.6]
#  [ 9.7]
#  [10.4]
#  [10.6]]

# %%
print(Y)
# Out:
# [ 39344.  46206.  37732.  43526.  39892.  56643.  60151.  54446.  64446.
#   57190.  63219.  55795.  56958.  57082.  61112.  67939.  66030.  83089.
#   81364.  93941.  91739.  98274. 101303. 113813. 109432. 105583. 116970.
#  112636. 122392. 121873.]

# %%
# Training and Testing
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# Regressor model
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
Y_pred_test = regressor.predict(X_test)     # predicted value of y_test
Y_pred_train = regressor.predict(X_train)

# %%
# Visualizing the Training Results
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='Blue')
plt.show()

# %%
# Visualizing the testing results
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_train,regressor.predict(X_train),color='Blue')
plt.show()
